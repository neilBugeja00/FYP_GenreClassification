# %%
import matplotlib.pyplot as plt
import librosa
import numpy as np
from matplotlib import cm

# %%
#Load audio file
sr = 44100
songTest = 'extracted_0.wav'
y, sr = librosa.load(songTest, duration=10)

# %%
melSpec = librosa.feature.melspectrogram(y=y, sr=sr)

# %%
# Display MFCCs as a heatmap
plt.figure(figsize=(10, 4))
plt.imshow(melSpec, interpolation='nearest', origin='lower', aspect='auto')
plt.colorbar()
plt.title('Mel Spectrogram')
plt.xlabel('Frame')
plt.ylabel('MFCC Coefficients')
plt.tight_layout()
plt.show()

# %%
#Compute MFCC
mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40)

# %%
#================LIBROSA DOCUMENTATION================

# %%
fig, ax = plt.subplots(nrows=2, sharex=True)


img = librosa.display.specshow(mfccs, x_axis='time', ax=ax[1])

fig.colorbar(img, ax=[ax[1]])

ax[1].set(title='MFCC')
# Out:
# [Text(0.5, 1.0, 'MFCC')]

# %%
#==================TO DISPLAY=====================

# %%
# Display MFCCs as a heatmap
#plt.figure(figsize=(10, 4))
#plt.imshow(mfccs, interpolation='nearest', origin='lower', aspect='auto')
#plt.colorbar()
#plt.title('MFCCs')
#plt.xlabel('Frame')
#plt.ylabel('MFCC Coefficients')
#plt.tight_layout()
#plt.show()

# %%
#==================TO USE IN CODE===================

# %%
# Display MFCCs as a heatmap
plt.figure(figsize=(10, 4))
plt.imshow(mfccs, interpolation='nearest', origin='lower', aspect='auto')
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots()
mfcc_data= np.swapaxes(mfccs, 0 ,1)
cax = ax.imshow(mfcc_data, interpolation='nearest', cmap=cm.coolwarm, origin='lower')
ax.set_title('MFCC')

plt.show()
